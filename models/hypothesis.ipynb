# %%
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.stattools import adfuller

from preprocess import VN30, TARGETS, _process_file

# %%
for symbol in VN30:
	df, _ = _process_file(symbol)
	p_values_list = [acorr_ljungbox(df[col], lags=[30], return_df=True)['lb_pvalue'].values[0] for col in TARGETS]
	print(f"p-values for {symbol}: {p_values_list}")
# Out:
# p-values for ACB: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for BCM: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for BID: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for BVH: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for CTG: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for FPT: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for GAS: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for GVR: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for HDB: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for HPG: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for LPB: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for MBB: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for MSN: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for MWG: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for PLX: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for SAB: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for SHB: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for SSB: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for SSI: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for STB: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for TCB: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for TPB: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for VCB: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for VHM: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for VIB: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for VIC: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for VJC: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for VNM: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for VPB: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# p-values for VRE: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]

# %%
# Đọc lại dữ liệu
for symbol in VN30:
	print(f"Processing {symbol}...")
	df, _ = _process_file(symbol)
	max_lag = 30 

	# Tạo ma trận p-value
	pval_matrix = pd.DataFrame(index=TARGETS, columns=TARGETS, dtype=float)

	# Kiểm định Granger cho từng cặp chiều (nguyên nhân → kết quả)
	for cause in TARGETS:
		for effect in TARGETS:
			if cause == effect:
				pval_matrix.loc[cause, effect] = np.nan
				continue
			# Dữ liệu gồm 2 cột: [effect, cause]
			test_result = grangercausalitytests(df[[effect, cause]], maxlag=max_lag, verbose=False)
			# Lấy p-value nhỏ nhất trong các lag
			min_pvalue = min(test_result[lag][0]['ssr_chi2test'][1] for lag in range(1, max_lag + 1))
			pval_matrix.loc[cause, effect] = min_pvalue
	
	print(pval_matrix)
# Out:
# Processing ACB...
#                 open           high            low     close
# open             NaN   3.186204e-07   1.503439e-15  0.000607
# high   3.544558e-255            NaN   9.899201e-45  0.008266
# low    5.943174e-198   1.433802e-18            NaN  0.002256
# close   0.000000e+00  3.975568e-170  6.264399e-250       NaN
# Processing BCM...
#                 open           high            low         close
# open             NaN   2.081378e-07   1.116691e-03  7.191078e-05
# high   3.800171e-231            NaN   3.464386e-82  3.539560e-09
# low     2.524267e-90   1.562626e-12            NaN  4.413814e-04
# close   0.000000e+00  3.637922e-138  5.443153e-280           NaN
# Processing BID...
#                 open           high            low     close
# open             NaN   8.563889e-11   7.969439e-17  0.005077
# high   2.119985e-270            NaN   6.828355e-56  0.000002
# low    3.152517e-207   7.229714e-11            NaN  0.118707
# close   0.000000e+00  1.253454e-144  7.727710e-276       NaN
# Processing BVH...
#                 open           high            low     close
# open             NaN   1.775270e-06   2.173077e-16  0.000049
# high   3.879583e-231            NaN   8.675106e-34  0.012099
# low    1.561762e-231   3.861503e-29            NaN  0.001141
# close   0.000000e+00  4.140257e-180  5.620938e-224       NaN
# Processing CTG...
#                 open           high            low     close
# open             NaN   3.815787e-19   5.275453e-13  0.000076
# high    0.000000e+00            NaN   2.430572e-45  0.000137
# low    4.001379e-200   1.306709e-12            NaN  0.000207
# close   0.000000e+00  1.797151e-170  1.233690e-222       NaN
# Processing FPT...
#                 open           high            low     close
# open             NaN   5.457401e-08   3.708790e-11  0.002540
# high   1.483241e-295            NaN   1.032734e-43  0.215970
# low    1.871488e-184   2.650205e-19            NaN  0.000007
# close   0.000000e+00  6.314800e-154  1.313841e-267       NaN
# Processing GAS...
#                 open           high            low         close
# open             NaN   1.708642e-09   2.188924e-11  4.517802e-07
# high   4.021818e-224            NaN   5.787546e-38  2.578574e-05
# low    1.330936e-199   1.990541e-17            NaN  1.078098e-03
# close   0.000000e+00  9.061504e-124  8.118324e-170           NaN
# Processing GVR...
#                 open          high            low     close
# open             NaN  3.264234e-10   3.271066e-23  0.000014
# high   1.088390e-220           NaN   5.870343e-13  0.000062
# low    2.025122e-232  8.934171e-42            NaN  0.007488
# close   0.000000e+00  0.000000e+00  1.939582e-269       NaN
# Processing HDB...
#                 open           high            low         close
# open             NaN   3.538618e-10   1.381325e-12  2.316378e-07
# high   5.136906e-251            NaN   1.557660e-35  4.397426e-03
# low    1.176391e-202   8.694191e-17            NaN  4.513879e-03
# close   0.000000e+00  1.612628e-156  3.135114e-239           NaN
# Processing HPG...
#                 open           high            low         close
# open             NaN   2.522168e-14   9.608016e-27  1.032449e-07
# high    0.000000e+00            NaN   1.431241e-36  3.616818e-04
# low    8.032219e-268   1.108371e-24            NaN  1.033527e-03
# close   0.000000e+00  4.112761e-182  9.615135e-234           NaN
# Processing LPB...
#                 open           high            low         close
# open             NaN   3.023330e-14   3.114704e-20  3.419572e-10
# high   1.435387e-234            NaN   4.216141e-34  1.106236e-10
# low    4.030924e-184   1.072483e-15            NaN  1.490890e-06
# close   0.000000e+00  3.475212e-201  5.876299e-311           NaN
# Processing MBB...
#                 open           high            low     close
# open             NaN   6.104686e-15   1.441506e-21  0.000003
# high   4.950758e-298            NaN   5.594324e-41  0.002922
# low    2.650477e-206   9.580470e-13            NaN  0.000024
# close   0.000000e+00  5.108769e-191  3.039839e-280       NaN
# Processing MSN...
#                 open           high            low     close
# open             NaN   1.717537e-13   3.806262e-07  0.000895
# high   3.682313e-288            NaN   1.354253e-56  0.000006
# low    7.888325e-217   2.048581e-17            NaN  0.005944
# close   0.000000e+00  3.268561e-147  1.914058e-244       NaN
# Processing MWG...
#                 open           high            low     close
# open             NaN   3.087769e-09   9.123643e-12  0.000384
# high   1.154290e-286            NaN   8.976907e-38  0.000002
# low    3.761763e-197   9.998621e-17            NaN  0.000017
# close   0.000000e+00  4.800149e-151  7.964369e-237       NaN
# Processing PLX...
#                 open           high            low     close
# open             NaN   3.006687e-06   5.417115e-08  0.000055
# high   1.143156e-193            NaN   1.362573e-27  0.031304
# low    1.176627e-203   1.290420e-39            NaN  0.004783
# close   0.000000e+00  1.342219e-177  1.831382e-170       NaN
# Processing SAB...
#                 open           high            low         close
# open             NaN   1.220328e-02   3.877375e-01  3.180317e-07
# high   5.244670e-135            NaN   5.752917e-46  8.639718e-08
# low    3.353860e-145   6.460935e-37            NaN  5.799613e-04
# close   0.000000e+00  5.481813e-131  3.946906e-173           NaN
# Processing SHB...
#                 open           high           low         close
# open             NaN   1.425344e-13  5.036244e-16  5.661472e-09
# high   1.695101e-231            NaN  1.345858e-30  3.555862e-04
# low    4.865536e-215   8.288117e-22           NaN  5.916751e-07
# close   0.000000e+00  2.132248e-233  0.000000e+00           NaN
# Processing SSB...
#                 open          high            low         close
# open             NaN  5.065154e-06   3.327701e-03  1.228695e-04
# high   1.650826e-200           NaN   1.229390e-78  5.706392e-12
# low     3.764486e-30  1.544599e-05            NaN  1.811430e-02
# close   0.000000e+00  5.451053e-51  1.974897e-195           NaN
# Processing SSI...
#                 open           high            low     close
# open             NaN   6.129368e-24   1.997980e-25  0.000779
# high    0.000000e+00            NaN   1.769785e-53  0.000459
# low    1.641648e-245   1.467651e-15            NaN  0.000003
# close   0.000000e+00  2.354966e-174  1.334393e-297       NaN
# Processing STB...
#                 open           high            low         close
# open             NaN   1.250432e-20   2.429251e-20  4.027580e-07
# high    0.000000e+00            NaN   1.094887e-37  6.751304e-05
# low    4.929093e-245   1.531664e-13            NaN  2.419327e-04
# close   0.000000e+00  1.439629e-199  2.422516e-264           NaN
# Processing TCB...
#                 open           high            low     close
# open             NaN   5.135869e-13   7.656938e-20  0.000627
# high   3.202849e-262            NaN   1.267067e-24  0.002823
# low    3.138698e-245   3.310472e-24            NaN  0.004049
# close   0.000000e+00  1.347104e-193  1.994471e-206       NaN
# Processing TPB...
#                 open           high            low     close
# open             NaN   2.082843e-10   6.158289e-11  0.000113
# high   3.815181e-290            NaN   5.970719e-38  0.005511
# low    1.835866e-188   1.165816e-12            NaN  0.002644
# close   0.000000e+00  4.361888e-161  1.229085e-200       NaN
# Processing VCB...
#                 open          high            low     close
# open             NaN  6.756190e-04   1.484349e-03  0.000659
# high   1.032660e-256           NaN   7.758896e-62  0.003585
# low    9.682530e-172  1.395955e-20            NaN  0.000210
# close   0.000000e+00  1.064357e-90  5.721037e-163       NaN
# Processing VHM...
#                 open           high            low     close
# open             NaN   2.767610e-05   8.977837e-07  0.027421
# high   5.490501e-238            NaN   8.197377e-41  0.000727
# low    1.244917e-197   2.922892e-23            NaN  0.038728
# close   0.000000e+00  1.039655e-145  4.829614e-176       NaN
# Processing VIB...
#                 open           high           low     close
# open             NaN   1.671210e-10  5.104312e-11  0.000394
# high   2.437960e-272            NaN  1.805014e-47  0.000004
# low    5.879633e-130   6.180640e-10           NaN  0.000023
# close   0.000000e+00  1.943207e-201  0.000000e+00       NaN
# Processing VIC...
#                 open           high            low     close
# open             NaN   1.210737e-07   2.100466e-03  0.081251
# high   2.940929e-230            NaN   2.660274e-48  0.013684
# low    2.146151e-157   1.304316e-26            NaN  0.001673
# close   0.000000e+00  1.455135e-126  8.019195e-171       NaN
# Processing VJC...
#                 open           high            low     close
# open             NaN   3.815033e-04   1.353683e-10  0.000908
# high   1.157548e-263            NaN   8.475215e-44  0.005962
# low    2.304446e-261   4.272265e-36            NaN  0.000494
# close   0.000000e+00  1.108858e-137  4.103969e-167       NaN
# Processing VNM...
#                 open           high            low     close
# open             NaN   1.055974e-06   7.970411e-09  0.019358
# high   2.143567e-293            NaN   1.775354e-47  0.004820
# low    3.328861e-251   4.774570e-21            NaN  0.006966
# close   0.000000e+00  4.373791e-105  3.841809e-154       NaN
# Processing VPB...
#                 open           high            low     close
# open             NaN   5.059271e-09   1.769267e-13  0.001979
# high   1.450076e-284            NaN   1.074108e-49  0.005549
# low    3.356070e-203   1.715437e-13            NaN  0.000487
# close   0.000000e+00  1.484062e-171  2.807805e-263       NaN
# Processing VRE...
#                 open           high            low     close
# open             NaN   5.530317e-07   9.636942e-07  0.000080
# high   5.031348e-247            NaN   1.527563e-45  0.002734
# low    1.779117e-174   1.836460e-17            NaN  0.012922
# close   0.000000e+00  5.380110e-145  2.022484e-194       NaN

# %%
def adf_test(series):
    result = adfuller(series, autolag='AIC')
    return result[1]  # Return p-value

for symbol in VN30:
	print(f"Processing {symbol}...")
	df, _ = _process_file(symbol)
	pvals_adf = []

	# Perform ADF test for each column and its first difference
	for col in TARGETS:
		original_p = adf_test(df[col])
		diff_p = adf_test(df[col].diff().dropna())
		pvals_adf.append([original_p, diff_p])

	# Create DataFrame for results
	adf_results = pd.DataFrame(pvals_adf, columns=["Original Series", "1st Difference"], index=TARGETS)
	print(adf_results)
# Out:
# Processing ACB...
#        Original Series  1st Difference
# open          0.777095    4.232630e-30
# high          0.760448    0.000000e+00
# low           0.794568    3.623264e-30
# close         0.755801    0.000000e+00
# Processing BCM...
#        Original Series  1st Difference
# open          0.539444    1.869708e-13
# high          0.581507    0.000000e+00
# low           0.575589    0.000000e+00
# close         0.522453    8.262781e-12
# Processing BID...
#        Original Series  1st Difference
# open          0.411611    0.000000e+00
# high          0.229944    2.525333e-30
# low           0.297085    2.885187e-18
# close         0.341987    2.537555e-27
# Processing BVH...
#        Original Series  1st Difference
# open          0.135900             0.0
# high          0.151728             0.0
# low           0.167578             0.0
# close         0.156512             0.0
# Processing CTG...
#        Original Series  1st Difference
# open          0.397294    7.642953e-28
# high          0.439879    1.424400e-20
# low           0.446975    0.000000e+00
# close         0.429467    0.000000e+00
# Processing FPT...
#        Original Series  1st Difference
# open          0.969218    1.096692e-19
# high          0.959105    1.779312e-19
# low           0.968370    1.058186e-11
# close         0.966451    1.757246e-19
# Processing GAS...
#        Original Series  1st Difference
# open          0.191478    0.000000e+00
# high          0.147738    6.551375e-20
# low           0.167762    2.600917e-21
# close         0.166523    2.047952e-21
# Processing GVR...
#        Original Series  1st Difference
# open          0.481732    7.260976e-20
# high          0.444211    0.000000e+00
# low           0.474427    1.810982e-19
# close         0.448214    0.000000e+00
# Processing HDB...
#        Original Series  1st Difference
# open          0.767939    5.269222e-18
# high          0.811171    0.000000e+00
# low           0.744186    0.000000e+00
# close         0.784533    0.000000e+00
# Processing HPG...
#        Original Series  1st Difference
# open          0.701885    0.000000e+00
# high          0.578778    1.165525e-11
# low           0.591159    3.028218e-12
# close         0.607378    1.485756e-11
# Processing LPB...
#        Original Series  1st Difference
# open          0.789467    2.003785e-27
# high          0.837264    0.000000e+00
# low           0.850198    0.000000e+00
# close         0.819402    1.504930e-23
# Processing MBB...
#        Original Series  1st Difference
# open          0.594968    0.000000e+00
# high          0.635875    0.000000e+00
# low           0.583826    1.275561e-29
# close         0.616878    0.000000e+00
# Processing MSN...
#        Original Series  1st Difference
# open          0.551336    0.000000e+00
# high          0.646167    1.522623e-21
# low           0.650669    5.414681e-14
# close         0.638705    1.051163e-12
# Processing MWG...
#        Original Series  1st Difference
# open          0.339121    3.531004e-15
# high          0.494089    0.000000e+00
# low           0.342840    4.973511e-15
# close         0.479958    4.845932e-12
# Processing PLX...
#        Original Series  1st Difference
# open          0.387208    0.000000e+00
# high          0.329912    2.214884e-26
# low           0.318585    0.000000e+00
# close         0.322012    1.815946e-27
# Processing SAB...
#        Original Series  1st Difference
# open          0.449148    6.788858e-20
# high          0.459557    0.000000e+00
# low           0.433405    0.000000e+00
# close         0.442167    0.000000e+00
# Processing SHB...
#        Original Series  1st Difference
# open          0.466783    0.000000e+00
# high          0.466581    2.180947e-11
# low           0.485456    0.000000e+00
# close         0.436320    2.134746e-30
# Processing SSB...
#        Original Series  1st Difference
# open          0.007877    7.540868e-12
# high          0.011078    3.036418e-21
# low           0.022600    1.460231e-20
# close         0.008736    1.098019e-23
# Processing SSI...
#        Original Series  1st Difference
# open          0.735916    2.041513e-26
# high          0.725450    4.139082e-25
# low           0.729785    6.876698e-11
# close         0.728445    2.639420e-26
# Processing STB...
#        Original Series  1st Difference
# open          0.611563    1.165350e-15
# high          0.672902    2.022725e-30
# low           0.670896    0.000000e+00
# close         0.668552    0.000000e+00
# Processing TCB...
#        Original Series  1st Difference
# open          0.677060    0.000000e+00
# high          0.629793    9.695300e-29
# low           0.631797    1.237114e-29
# close         0.663014    0.000000e+00
# Processing TPB...
#        Original Series  1st Difference
# open          0.625372    3.098369e-09
# high          0.651293    1.609724e-26
# low           0.627434    8.608799e-09
# close         0.623355    9.332450e-12
# Processing VCB...
#        Original Series  1st Difference
# open          0.390711    0.000000e+00
# high          0.377596    0.000000e+00
# low           0.355841    2.090021e-25
# close         0.300611    0.000000e+00
# Processing VHM...
#        Original Series  1st Difference
# open          0.465381    0.000000e+00
# high          0.444753    0.000000e+00
# low           0.382132    0.000000e+00
# close         0.472162    1.653986e-20
# Processing VIB...
#        Original Series  1st Difference
# open          0.603237    0.000000e+00
# high          0.594573    6.165307e-30
# low           0.609441    1.427777e-29
# close         0.623328    0.000000e+00
# Processing VIC...
#        Original Series  1st Difference
# open          0.811595             0.0
# high          0.765575             0.0
# low           0.805084             0.0
# close         0.828505             0.0
# Processing VJC...
#        Original Series  1st Difference
# open          0.271134    1.753194e-28
# high          0.191019    0.000000e+00
# low           0.209133    0.000000e+00
# close         0.217838    7.349269e-23
# Processing VNM...
#        Original Series  1st Difference
# open          0.272311             0.0
# high          0.361417             0.0
# low           0.308548             0.0
# close         0.359021             0.0
# Processing VPB...
#        Original Series  1st Difference
# open          0.621341    1.144980e-09
# high          0.638363    0.000000e+00
# low           0.633533    5.027376e-09
# close         0.632667    3.158865e-09
# Processing VRE...
#        Original Series  1st Difference
# open          0.040083             0.0
# high          0.039650             0.0
# low           0.021505             0.0
# close         0.029562             0.0
