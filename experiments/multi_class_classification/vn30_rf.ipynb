# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[1]
sys.path.append(str(PROJECT_ROOT))

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
from loaders._load_vn30_multi_class_tree import preprocess, VN30, TARGETS
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import balanced_accuracy_score

# %%
X_train, Y_train = preprocess("ACB", verbose=True)["train"]
# Out:
# === Preprocessing ACB ===
# Train: (1227, 120), Val: (0, 120), Test: (285, 120)
# Class 0 (strong_down): 99 samples
# Class 1 (weak_down): 282 samples
# Class 2 (sideways): 427 samples
# Class 3 (weak_up): 285 samples
# Class 4 (strong_up): 134 samples

# %%
mean_accuracy = []
for symbol in VN30:
    data = preprocess(symbol, lag=30)

    X_train, Y_train = data['train']
    X_test, Y_test = data['test']
    classes = data['classes']

    model = RandomForestClassifier(
        n_estimators=50,
        max_depth=10,
        random_state=42,
        n_jobs=-1
    )

    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    accuracy = balanced_accuracy_score(Y_test, Y_pred)
    mean_accuracy.append(accuracy)
    print(f"Accuracy for {symbol}: {accuracy:.4f}")

print(f"Mean accuracy: {np.mean(mean_accuracy):.4f}")
print(f"Standard deviation of accuracy: {np.std(mean_accuracy):.4f}")
# Out:
# Accuracy for ACB: 0.2000
# Accuracy for BCM: 0.1673
# Accuracy for BID: 0.1911
# Accuracy for BVH: 0.2061
# Accuracy for CTG: 0.1835
# Accuracy for FPT: 0.2000
# Accuracy for GAS: 0.1968
# Accuracy for GVR: 0.2226
# Accuracy for HDB: 0.2000
# Accuracy for HPG: 0.1796
# Accuracy for LPB: 0.2025
# Accuracy for MBB: 0.2374
# Accuracy for MSN: 0.2082
# Accuracy for MWG: 0.2036
# Accuracy for PLX: 0.2290
# Accuracy for SAB: 0.2635
# Accuracy for SHB: 0.1910
# Accuracy for SSB: 0.1849
# Accuracy for SSI: 0.2154
# Accuracy for STB: 0.2548
# Accuracy for TCB: 0.1907
# Accuracy for TPB: 0.2080
# Accuracy for VCB: 0.1754
# Accuracy for VHM: 0.1805
# Accuracy for VIB: 0.2185
# Accuracy for VIC: 0.2459
# Accuracy for VJC: 0.2104
# Accuracy for VNM: 0.2349
# Accuracy for VPB: 0.2078
# Accuracy for VRE: 0.2329
# Mean accuracy: 0.2081
# Standard deviation of accuracy: 0.0234

# %%
# Nếu dùng label các ngày trước đó như là một đặc trưng -> có tốt hơn
mean_accuracy = []
for symbol in VN30:
    data = preprocess(symbol, lag=30, lag_label=True)

    X_train, Y_train = data['train']
    X_test, Y_test = data['test']
    classes = data['classes']

    model = RandomForestClassifier(
        n_estimators=50,
        max_depth=10,
        random_state=42,
        n_jobs=-1
    )

    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    accuracy = balanced_accuracy_score(Y_test, Y_pred)
    mean_accuracy.append(accuracy)
    print(f"Accuracy for {symbol}: {accuracy:.4f}")

print(f"Mean accuracy: {np.mean(mean_accuracy):.4f}")
print(f"Standard deviation of accuracy: {np.std(mean_accuracy):.4f}")
# Out:
# Accuracy for ACB: 0.1985
# Accuracy for BCM: 0.1752
# Accuracy for BID: 0.1880
# Accuracy for BVH: 0.2213
# Accuracy for CTG: 0.1775
# Accuracy for FPT: 0.1971
# Accuracy for GAS: 0.2232
# Accuracy for GVR: 0.2568
# Accuracy for HDB: 0.2000
# Accuracy for HPG: 0.1766
# Accuracy for LPB: 0.2235
# Accuracy for MBB: 0.2404
# Accuracy for MSN: 0.2099
# Accuracy for MWG: 0.2138
# Accuracy for PLX: 0.2147
# Accuracy for SAB: 0.2431
# Accuracy for SHB: 0.2069
# Accuracy for SSB: 0.1666
# Accuracy for SSI: 0.2106
# Accuracy for STB: 0.2396
# Accuracy for TCB: 0.1897
# Accuracy for TPB: 0.2072
# Accuracy for VCB: 0.2202
# Accuracy for VHM: 0.2008
# Accuracy for VIB: 0.2492
# Accuracy for VIC: 0.2177
# Accuracy for VJC: 0.1986
# Accuracy for VNM: 0.2316
# Accuracy for VPB: 0.1782
# Accuracy for VRE: 0.1865
# Mean accuracy: 0.2088
# Standard deviation of accuracy: 0.0232

# %%
# Nếu dùng label các ngày trước đó như là một đặc trưng -> có tốt hơn
mean_accuracy = []
for symbol in VN30:
    data = preprocess(symbol, lag=30, lag_label=True)

    X_train, Y_train = data['train']
    X_test, Y_test = data['test']
    classes = data['classes']

    model = RandomForestClassifier(
        n_estimators=100,
        max_depth=10,
        random_state=42,
        n_jobs=-1
    )

    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    accuracy = balanced_accuracy_score(Y_test, Y_pred)
    mean_accuracy.append(accuracy)
    print(f"Accuracy for {symbol}: {accuracy:.4f}")

print(f"Mean accuracy: {np.mean(mean_accuracy):.4f}")
print(f"Standard deviation of accuracy: {np.std(mean_accuracy):.4f}")
# Out:
# Accuracy for ACB: 0.2242
# Accuracy for BCM: 0.1627
# Accuracy for BID: 0.1966
# Accuracy for BVH: 0.2086
# Accuracy for CTG: 0.1864
# Accuracy for FPT: 0.1832
# Accuracy for GAS: 0.2123
# Accuracy for GVR: 0.2429
# Accuracy for HDB: 0.2000
# Accuracy for HPG: 0.1925
# Accuracy for LPB: 0.2235
# Accuracy for MBB: 0.2919
# Accuracy for MSN: 0.2274
# Accuracy for MWG: 0.2119
# Accuracy for PLX: 0.2242
# Accuracy for SAB: 0.2551
# Accuracy for SHB: 0.1897
# Accuracy for SSB: 0.1908
# Accuracy for SSI: 0.2203
# Accuracy for STB: 0.2546
# Accuracy for TCB: 0.2100
# Accuracy for TPB: 0.2092
# Accuracy for VCB: 0.1930
# Accuracy for VHM: 0.1818
# Accuracy for VIB: 0.2304
# Accuracy for VIC: 0.2420
# Accuracy for VJC: 0.1963
# Accuracy for VNM: 0.2250
# Accuracy for VPB: 0.1884
# Accuracy for VRE: 0.1932
# Mean accuracy: 0.2123
# Standard deviation of accuracy: 0.0266
